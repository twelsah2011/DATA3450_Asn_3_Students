# %%
#import thinkplot
#import thinkstats2
import pandas as pd
import numpy as np
import math
import scipy.stats as ss
import thinkplot
import thinkstats2
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

##Seaborn for fancy plots. 
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (15,5)

# %% [markdown]
# # Assignment 3 - Basic Predictions and Regression

# %% [markdown]
# ## Questions
#
# ### Part 1 - Election Prediction
#
# Suppose you are looking at an election in a fictional province. There are 7 total elctoral districts, and the winner in each district is determined by a first-past-the-post system (what we have in Canada - the most votes wins, regardless of share). There are two parties - the Purples and the Yellows. Whoever controls the most seats will be the ruling party - so in our 2 party scenario, the party who wins 4 or more of the districts will govern. There is an election every year, they love voting.
#
# Recent polling indicating the expected vote share in each district is shown in the "dist_polls" table below. These values are a composite of several polls that the experts have combined and weighted. The "Purple" values show the expected vote share of the Purple party, along with the variance of that expectation and the number of polls that were combined to get that result.
#
# As well, research has shown that the vote distribution is impacted by voter turnout. In general, the more people vote, the more the vote split shifts towards the Yellow party. We have data on past elections and the results, we expect that the turnout will be in line with the past elections - or more specifically, we have no reason to expect it to differ. This impact is measured in the table in code below - that table shows the voter turnout, in a percentage, as well as the change in the Yellow party's vote share (also in percentage) as compared to the polling averages. For example, if one row showed "52" and ".8", that would mean that voter turnout was 52%, and the Yellow party got .8% higher of a vote share than the polling showed.
#
# <b>What is the probability that the Purple Party controls the government after the election?</b>
#
# <b>Note:</b> the errors and confidence intervals are not totally trivial. As part of the written answer, offer an evaluation of your confidence in the prediction, and why you think that. This is not a question with one specific error, your estimation will have some expected errors, somewhere. You may not have the tools to calculate it all the way through, that's fine.

# %% [markdown]
# ### Question 1 - Your Answer in English
#
# Please fill in (and extend if required) the list here to explain what you did. There are multiple reasonable things you could do to approach this, so please note what you did here. For most people I assume this will be about 3-5 statements - you don't need to explain the internals of things we covered (e.g. if there's a hypothesis test, you don't need to explain how that works), just how you structured your approach to the problem.
#
# <ul>
# <li>
# <li>
# <li>
# <li> <b> What do you think about the error/accuracy:</b>
# </ul>

# %% [markdown]
# ##### Setup Poll Data
#
# The dataframe "dist_polls" contains all of the polls for each seat. Each value is expressed as expected vote share (as a ratio) for the <b>Purple</b> party. The Yellow party can be safely assumed to get the rest of the votes.

# %%
# Please don't edit this part. 
# Setup polling data. 
districts = [1,2,3,4,5,6,7]
dist_polls = pd.DataFrame(districts, columns={"district"})

dist_polls["Poll_1"] = [.55, .49, .51, .6, .41, .46, .54]
dist_polls["Poll_2"] = [.53, .51, .51, .62, .44, .48, .53]
dist_polls["Poll_3"] = [.51, .49, .53, .61, .42, .46, .52]
dist_polls["Poll_4"] = [.47, .48, .51, .54, .45, .45, .51]
dist_polls["Poll_5"] = [.61, .52, .49, .73, .44, .51, .53]
dist_polls["Poll_6"] = [.54, .45, .51, .61, .47, .52, .52]
dist_polls["Poll_7"] = [.55, .47, .5, .56, .47, .46, .56]
dist_polls["Poll_8"] = [.53, .49, .51, .55, .43, .49, .55]
dist_polls["Poll_9"] = [.57, .39, .52, .57, .53, .43, .53]


dist_polls.head(7)
# Out:
#    district  Poll_1  Poll_2  Poll_3  Poll_4  Poll_5  Poll_6  Poll_7  Poll_8  \
# 0         1    0.55    0.53    0.51    0.47    0.61    0.54    0.55    0.53
# 1         2    0.49    0.51    0.49    0.48    0.52    0.45    0.47    0.49
# 2         3    0.51    0.51    0.53    0.51    0.49    0.51    0.50    0.51
# 3         4    0.60    0.62    0.61    0.54    0.73    0.61    0.56    0.55
# 4         5    0.41    0.44    0.42    0.45    0.44    0.47    0.47    0.43
# 5         6    0.46    0.48    0.46    0.45    0.51    0.52    0.46    0.49
# 6         7    0.54    0.53    0.52    0.51    0.53    0.52    0.56    0.55
#
#    Poll_9
# 0    0.57
# 1    0.39
# 2    0.52
# 3    0.57
# 4    0.53
# 5    0.43
# 6    0.53

# %% [markdown]
# ### Polling Distribution

# %%
def getPollDist(pollDF, toDrop="district"):
    dists = []
    for _, row in pollDF.iterrows():
        polls = row[1:-1]
        tmpMean = np.mean(polls)
        tmpStd = np.std(polls)
        dists.append((tmpMean, tmpStd))
        #sns.kdeplot(polls)
        #print(polls)
    return dists

# %%
def simElec(meanVotes, stdVotes, n=100):
    votes = np.random.normal(loc=meanVotes, scale=stdVotes, size=n)
    #print("MEAN:", np.mean(votes))
    return np.mean(votes)

# %%
def simElecBin(meanVotes, n=100):
    votes = np.random.binomial(n=n, p=meanVotes)
    #print("MEAN:", np.mean(votes)/n)
    return np.mean(votes)/n

# %%
dists = getPollDist(dist_polls)

elections = []
for i in dists:
    tmpMean = float(i[0])
    tmpStd = float(i[1])
    sims = simElec(tmpMean, tmpStd)
    elections.append(sims)
elections
# Out:
# [0.5454885267065401,
#  0.4879620324611143,
#  0.510004465700192,
#  0.6067520474641045,
#  0.443959531907929,
#  0.475124397540946,
#  0.5344485581587418]

# %%
def adjustVotes(elections, adjustment):
    post_adj = []
    for i in elections:
        tmp = i + adjustment
        post_adj.append(tmp)
    return post_adj

# %% [markdown]
# ##### Setup Turnout Data
#
# The dataframe "past_vte_table" shows the voter turnout, along with the impact on the votes counted for the <b>Yellow party</b>, all expressed as percentages. For example, if in one row the turnout is .45 and the Yellow_improvement is -.04, that means that 45% of the populace turned out to vote, and the Yellow party got 4% fewer votes than polling indicated.

# %%
# Please don't edit this part. 
# Setup vote data. 
voter_turnout_history = [.53, .51, .48, .55, .54, .59, .49, .57, .56]
past_vote_table = pd.DataFrame(voter_turnout_history, columns={"voter_turn_percentage"})
past_vote_table["Yellow_improvement"] = [.012, .023, -.017, .031, .030, -.004, -.03, .042, .029]
past_vote_table["year"] = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
past_vote_table.head()
# Out:
#    voter_turn_percentage  Yellow_improvement  year
# 0                   0.53               0.012  2013
# 1                   0.51               0.023  2014
# 2                   0.48              -0.017  2015
# 3                   0.55               0.031  2016
# 4                   0.54               0.030  2017

# %%
sns.scatterplot(data = past_vote_table, x = "voter_turn_percentage", y="Yellow_improvement")
# Out:
# <AxesSubplot:xlabel='voter_turn_percentage', ylabel='Yellow_improvement'>

# %%
y = np.array(past_vote_table["Yellow_improvement"]).reshape(-1,1)
x = np.array(past_vote_table["voter_turn_percentage"]).reshape(-1,1)

model = LinearRegression().fit(x, y)
adj = -model.predict(np.array(.6).reshape(1,-1))[0][0]
adj
# Out:
# -0.0377535934291581

# %% [markdown]
# ## Start Your Work
#
# ### Part 1 - Election

# %%
# Do some stuff

dists = getPollDist(dist_polls)

purpWins = 0

for sim in range(1000):
    preAdj = []
    postAdj = []
    purpSeats = 0
    for i in dists:
        # estimate via normal or binomial
        #sims = simElec(i[0], i[1])
        sims = simElecBin(i[0])
        preAdj.append(sims)
    postAdj = adjustVotes(preAdj, adj)
    #print(preAdj)
    #print(postAdj)
    for i in postAdj:
        if i >= .5:
            purpSeats += 1
    #print(purpSeats)
    if purpSeats >= 4:
        purpWins += 1
    print("Purple seats:", purpSeats)
print("Election wins:", purpWins)
# Out:
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 1
# Purple seats: 1
# Purple seats: 1
# Purple seats: 1
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 1
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 0
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 5
# Purple seats: 4
# Purple seats: 4
# Purple seats: 1
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 4
# Purple seats: 4
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 0
# Purple seats: 1
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 1
# Purple seats: 3
# Purple seats: 4
# Purple seats: 4
# Purple seats: 2
# Purple seats: 1
# Purple seats: 5
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 0
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 5
# Purple seats: 3
# Purple seats: 5
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 5
# Purple seats: 3
# Purple seats: 3
# Purple seats: 5
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 1
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 1
# Purple seats: 1
# Purple seats: 4
# Purple seats: 3
# Purple seats: 6
# Purple seats: 1
# Purple seats: 1
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 5
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 0
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 4
# Purple seats: 5
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 0
# Purple seats: 5
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 5
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 0
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 5
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 1
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 4
# Purple seats: 1
# Purple seats: 4
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 4
# Purple seats: 1
# Purple seats: 4
# Purple seats: 3
# Purple seats: 4
# Purple seats: 4
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 1
# Purple seats: 1
# Purple seats: 2
# Purple seats: 5
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 4
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 1
# Purple seats: 4
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 4
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 4
# Purple seats: 1
# Purple seats: 5
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 1
# Purple seats: 1
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 5
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 5
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 1
# Purple seats: 5
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 5
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 1
# Purple seats: 1
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 4
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 1
# Purple seats: 4
# Purple seats: 5
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 5
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 1
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 1
# Purple seats: 2
# Purple seats: 4
# Purple seats: 4
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 0
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 1
# Purple seats: 3
# Purple seats: 1
# Purple seats: 4
# Purple seats: 5
# Purple seats: 4
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 0
# Purple seats: 4
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 4
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 0
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 4
# Purple seats: 5
# Purple seats: 4
# Purple seats: 2
# Purple seats: 1
# Purple seats: 1
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 1
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 5
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 0
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 1
# Purple seats: 1
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 1
# Purple seats: 4
# Purple seats: 1
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 4
# Purple seats: 1
# Purple seats: 0
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 0
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 5
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 1
# Purple seats: 3
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 4
# Purple seats: 4
# Purple seats: 4
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 1
# Purple seats: 4
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 1
# Purple seats: 1
# Purple seats: 4
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 0
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 4
# Purple seats: 1
# Purple seats: 3
# Purple seats: 1
# Purple seats: 1
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 5
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 2
# Purple seats: 1
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Purple seats: 4
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 4
# Purple seats: 2
# Purple seats: 4
# Purple seats: 3
# Purple seats: 3
# Purple seats: 1
# Purple seats: 2
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 3
# Purple seats: 5
# Purple seats: 2
# Purple seats: 3
# Purple seats: 1
# Purple seats: 3
# Purple seats: 3
# Purple seats: 2
# Purple seats: 2
# Election wins: 169

# %% [markdown]
# ### Part 2 - Regression
#
# <b>Use the data provided to try to predict the wage. </b>
#
# The data is from FIFA rankings for players. You don't need to know anything about soccer or video games for this, so if these values are meaningless to you, just treat them as numbers and you'll be fine. All of the features are rankings are evaluations of how good different soccar players are at different skills.

# %% [markdown]
# #### Answer in English
#
# Please fill in (and extend if required) the list here to explain what you did. There are multiple reasonable things you could do to approach this, so please note what you did here. For most people I assume this will be about 3-5 statements - you don't need to explain the internals of things we covered (e.g. if there's a hypothesis test, you don't need to explain how that works), just how you structured your approach to the problem.
#
# <ul>
# <li>
# <li>
# <li>
# </ul>

# %%
df = pd.read_csv("players_20_2.csv")
df.head()
# Out:
#    wage_eur  attacking_crossing  attacking_finishing  \
# 0    565000                  88                   95
# 1    405000                  84                   94
# 2    290000                  87                   87
# 3    125000                  13                   11
# 4    470000                  81                   84
#
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                          70                       92                 88
# 1                          89                       83                 87
# 2                          62                       87                 87
# 3                          15                       43                 13
# 4                          61                       89                 83
#
#    skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  ...  \
# 0               97           93                 94                  92  ...
# 1               89           81                 76                  77  ...
# 2               96           88                 87                  81  ...
# 3               12           13                 14                  40  ...
# 4               95           83                 79                  83  ...
#
#    power_long_shots  mentality_aggression  mentality_interceptions  \
# 0                94                    48                       40
# 1                93                    63                       29
# 2                84                    51                       36
# 3                12                    34                       19
# 4                80                    54                       41
#
#    mentality_positioning  mentality_vision  mentality_penalties  \
# 0                     94                94                   75
# 1                     95                82                   85
# 2                     87                90                   90
# 3                     11                65                   11
# 4                     87                89                   88
#
#    mentality_composure  defending_marking  defending_standing_tackle  \
# 0                   96                 33                         37
# 1                   95                 28                         32
# 2                   94                 27                         26
# 3                   68                 27                         12
# 4                   91                 34                         27
#
#    defending_sliding_tackle
# 0                        26
# 1                        24
# 2                        29
# 3                        18
# 4                        22
#
# [5 rows x 30 columns]

# %%
df.describe().T
# Out:
#                               count         mean           std   min     25%  \
# wage_eur                    18278.0  9456.942773  21351.714095   0.0  1000.0
# attacking_crossing          18278.0    49.718405     18.325403   5.0    38.0
# attacking_finishing         18278.0    45.590218     19.594609   2.0    30.0
# attacking_heading_accuracy  18278.0    52.221468     17.428429   5.0    44.0
# attacking_short_passing     18278.0    58.748003     14.679653   7.0    54.0
# attacking_volleys           18278.0    42.809388     17.701815   3.0    30.0
# skill_dribbling             18278.0    55.596509     18.929118   4.0    50.0
# skill_curve                 18278.0    47.325692     18.422991   6.0    34.0
# skill_fk_accuracy           18278.0    42.708885     17.433612   4.0    31.0
# skill_long_passing          18278.0    52.768848     15.246454   8.0    43.0
# skill_ball_control          18278.0    58.461976     16.741878   5.0    54.0
# movement_acceleration       18278.0    64.299923     15.042232  12.0    56.0
# movement_sprint_speed       18278.0    64.415746     14.847763  11.0    57.0
# movement_agility            18278.0    63.504924     14.808380  11.0    55.0
# movement_reactions          18278.0    61.752544      9.135613  21.0    56.0
# movement_balance            18278.0    63.856439     14.201559  12.0    56.0
# power_shot_power            18278.0    58.181694     13.326083  14.0    48.0
# power_jumping               18278.0    64.928165     11.934059  19.0    58.0
# power_stamina               18278.0    62.889485     16.017954  12.0    56.0
# power_strength              18278.0    65.234763     12.534811  20.0    58.0
# power_long_shots            18278.0    46.812945     19.322343   4.0    32.0
# mentality_aggression        18278.0    55.742149     17.318157   9.0    44.0
# mentality_interceptions     18278.0    46.380239     20.775812   3.0    25.0
# mentality_positioning       18278.0    50.072163     19.594022   2.0    39.0
# mentality_vision            18278.0    53.609749     13.955626   9.0    44.0
# mentality_penalties         18278.0    48.383357     15.708099   7.0    39.0
# mentality_composure         18278.0    58.528778     11.880840  12.0    51.0
# defending_marking           18278.0    46.848889     20.091287   1.0    29.0
# defending_standing_tackle   18278.0    47.640333     21.585641   5.0    27.0
# defending_sliding_tackle    18278.0    45.606631     21.217734   3.0    24.0
#
#                                50%     75%       max
# wage_eur                    3000.0  8000.0  565000.0
# attacking_crossing            54.0    64.0      93.0
# attacking_finishing           49.0    62.0      95.0
# attacking_heading_accuracy    56.0    64.0      93.0
# attacking_short_passing       62.0    68.0      92.0
# attacking_volleys             44.0    56.0      90.0
# skill_dribbling               61.0    68.0      97.0
# skill_curve                   49.0    62.0      94.0
# skill_fk_accuracy             41.0    56.0      94.0
# skill_long_passing            56.0    64.0      92.0
# skill_ball_control            63.0    69.0      96.0
# movement_acceleration         67.0    75.0      97.0
# movement_sprint_speed         67.0    75.0      96.0
# movement_agility              66.0    74.0      96.0
# movement_reactions            62.0    68.0      96.0
# movement_balance              66.0    74.0      97.0
# power_shot_power              59.0    68.0      95.0
# power_jumping                 66.0    73.0      95.0
# power_stamina                 66.0    74.0      97.0
# power_strength                66.0    74.0      97.0
# power_long_shots              51.0    62.0      94.0
# mentality_aggression          58.0    69.0      95.0
# mentality_interceptions       52.0    64.0      92.0
# mentality_positioning         55.0    64.0      95.0
# mentality_vision              55.0    64.0      94.0
# mentality_penalties           49.0    60.0      92.0
# mentality_composure           60.0    67.0      96.0
# defending_marking             52.0    64.0      94.0
# defending_standing_tackle     55.0    66.0      92.0
# defending_sliding_tackle      52.0    64.0      90.0

# %%
#sns.pairplot(df.sample(100))

# %%
sns.kdeplot(df["wage_eur"])
# Out:
# <AxesSubplot:xlabel='wage_eur', ylabel='Density'>

# %%
sns.kdeplot(np.log(df["wage_eur"]))
# Out:
# /Users/akeems/opt/anaconda3/envs/ml3950/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <AxesSubplot:xlabel='wage_eur', ylabel='Density'>

# %% [markdown]
# #### Clean some data

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# wage_eur                      0
# attacking_crossing            0
# defending_standing_tackle     0
# defending_marking             0
# mentality_composure           0
# mentality_penalties           0
# mentality_vision              0
# mentality_positioning         0
# mentality_interceptions       0
# mentality_aggression          0
# power_long_shots              0
# power_strength                0
# power_stamina                 0
# power_jumping                 0
# power_shot_power              0
# movement_balance              0
# movement_reactions            0
# movement_agility              0
# movement_sprint_speed         0
# movement_acceleration         0
# skill_ball_control            0
# skill_long_passing            0
# skill_fk_accuracy             0
# skill_curve                   0
# skill_dribbling               0
# attacking_volleys             0
# attacking_short_passing       0
# attacking_heading_accuracy    0
# attacking_finishing           0
# defending_sliding_tackle      0
# dtype: int64

# %%
df2 = df[df["wage_eur"] > 10]
df2 = df[df["wage_eur"] < 300000]
y = np.array(df2["wage_eur"]).reshape(-1,1)
x = np.array(df2.drop(columns={"wage_eur"}))
print(x.shape, y.shape)

scaler = MinMaxScaler()
xTrain_, xTest_, yTrain, yTest = train_test_split(x,y)

xTrain = scaler.fit_transform(xTrain_)
xTest = scaler.transform(xTest_)

model = LinearRegression().fit(xTrain, yTrain)
preds = model.predict(xTest)
r2 = model.score(xTest, yTest)
rmse = mean_squared_error(yTest, preds, squared=False)
print("RMSE:", rmse, "\nR2:", r2)
# Out:
# (18267, 29) (18267, 1)
# RMSE: 16968.080765609106
# R2: 0.30774946504304745

# %% [markdown]
# #### Examine Colinerarity

# %%
# Import library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

#Function will check the VIF of each variable in a DF and return the results in another DF
def calc_vif(X):
    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return(vif)

#Check VIFs
vifs_1 = calc_vif(df2).sort_values(by="VIF", ascending=False)
vifs_1
# Out:
#                      variables         VIF
# 10          skill_ball_control  258.893158
# 4      attacking_short_passing  227.973333
# 11       movement_acceleration  177.023852
# 28   defending_standing_tackle  165.746011
# 6              skill_dribbling  164.837693
# 12       movement_sprint_speed  149.291715
# 29    defending_sliding_tackle  135.196516
# 14          movement_reactions  107.319123
# 13            movement_agility   97.179914
# 9           skill_long_passing   96.094741
# 26         mentality_composure   89.440625
# 16            power_shot_power   77.569439
# 23       mentality_positioning   77.198951
# 2          attacking_finishing   74.104704
# 22     mentality_interceptions   72.278393
# 20            power_long_shots   66.396226
# 24            mentality_vision   65.936653
# 15            movement_balance   65.477485
# 18               power_stamina   60.718317
# 19              power_strength   55.650373
# 7                  skill_curve   54.947920
# 1           attacking_crossing   52.202142
# 25         mentality_penalties   51.605269
# 3   attacking_heading_accuracy   51.468688
# 27           defending_marking   50.175067
# 5            attacking_volleys   48.636829
# 17               power_jumping   46.797001
# 21        mentality_aggression   43.508378
# 8            skill_fk_accuracy   34.983461
# 0                     wage_eur    1.602146

# %%
cols_rem_1 = vifs_1["variables"].to_list()
cols_rem_1
# Out:
# ['skill_ball_control',
#  'attacking_short_passing',
#  'movement_acceleration',
#  'defending_standing_tackle',
#  'skill_dribbling',
#  'movement_sprint_speed',
#  'defending_sliding_tackle',
#  'movement_reactions',
#  'movement_agility',
#  'skill_long_passing',
#  'mentality_composure',
#  'power_shot_power',
#  'mentality_positioning',
#  'attacking_finishing',
#  'mentality_interceptions',
#  'power_long_shots',
#  'mentality_vision',
#  'movement_balance',
#  'power_stamina',
#  'power_strength',
#  'skill_curve',
#  'attacking_crossing',
#  'mentality_penalties',
#  'attacking_heading_accuracy',
#  'defending_marking',
#  'attacking_volleys',
#  'power_jumping',
#  'mentality_aggression',
#  'skill_fk_accuracy',
#  'wage_eur']

# %%
df2_filt_1 = df2.drop(columns=cols_rem_1[0:7])
df2_filt_1.head()
# Out:
#    wage_eur  attacking_crossing  attacking_finishing  \
# 2    290000                  87                   87
# 3    125000                  13                   11
# 6    250000                  18                   14
# 7    200000                  53                   52
# 9    240000                  79                   90
#
#    attacking_heading_accuracy  attacking_volleys  skill_curve  \
# 2                          62                 87           88
# 3                          15                 13           13
# 6                          11                 14           18
# 7                          86                 45           60
# 9                          59                 79           83
#
#    skill_fk_accuracy  skill_long_passing  movement_agility  \
# 2                 87                  81                96
# 3                 14                  40                67
# 6                 12                  63                37
# 7                 70                  81                61
# 9                 69                  75                91
#
#    movement_reactions  ...  power_stamina  power_strength  power_long_shots  \
# 2                  92  ...             81              49                84
# 3                  88  ...             41              78                12
# 6                  86  ...             35              78                10
# 7                  88  ...             75              92                64
# 9                  92  ...             85              73                84
#
#    mentality_aggression  mentality_interceptions  mentality_positioning  \
# 2                    51                       36                     87
# 3                    34                       19                     11
# 6                    43                       22                     11
# 7                    82                       89                     47
# 9                    63                       55                     92
#
#    mentality_vision  mentality_penalties  mentality_composure  \
# 2                90                   90                   94
# 3                65                   11                   68
# 6                70                   25                   70
# 7                65                   62                   89
# 9                84                   77                   91
#
#    defending_marking
# 2                 27
# 3                 27
# 6                 25
# 7                 91
# 9                 38
#
# [5 rows x 23 columns]

# %%
y1 = np.array(df2_filt_1["wage_eur"]).reshape(-1,1)
x1 = np.array(df2_filt_1.drop(columns={"wage_eur"}))

xTrain_1, xTest_1, yTrain1, yTest1 = train_test_split(x1,y1)

xTrain1 = scaler.fit_transform(xTrain_1)
xTest1 = scaler.transform(xTest_1)

model1 = LinearRegression().fit(xTrain1, yTrain1)
preds1 = model1.predict(xTest1)
r21 = model1.score(xTest1, yTest1)
rmse1 = mean_squared_error(yTest1, preds1, squared=False)
print("RMSE:", rmse1, "\nR2:", r21)
# Out:
# RMSE: 17109.563200106837
# R2: 0.2971295859581876

# %%
#sns.pairplot(df2_filt_1.sample(100))

# %% [markdown]
# With collinearity and log transform 具有共線性和對數變換

# %%
df2_filt_1["wage_eur2"] = df2_filt_1["wage_eur"] + 1
y2 = np.array(np.log(df2_filt_1["wage_eur2"])).reshape(-1,1)
x2 = np.array(df2_filt_1.drop(columns={"wage_eur", "wage_eur2"}))

xTrain2, xTest2, yTrain2, yTest2 = train_test_split(x2,y2)

model2 = LinearRegression().fit(xTrain2, yTrain2)
preds2 = model2.predict(xTest2)
r22 = model2.score(xTest2, yTest2)
rmse2 = mean_squared_error(yTest2, preds2, squared=False)
print("RMSE:", rmse2, "\nR2:", r22)
# Out:
# RMSE: 1.292409715678005
# R2: 0.2993875555703167

# %% [markdown]
# Try a polynomial transformation.
# 嘗試多項式變換。

# %%
#df2_filt_1["wage_eur2"] = df2_filt_1["wage_eur"] + 1
#y3 = np.array(np.log(df2_filt_1["wage_eur2"])).reshape(-1,1)
#x3 = np.array(df2_filt_1.drop(columns={"wage_eur", "wage_eur2"}))
y3 = np.array(df2_filt_1["wage_eur"]).reshape(-1,1)
x3 = np.array(df2_filt_1.drop(columns={"wage_eur"}))

xTrain3, xTest3, yTrain3, yTest3 = train_test_split(x3,y3)

poly = PolynomialFeatures(degree=2)
model3 = make_pipeline(poly, LinearRegression())
model3.fit(xTrain3, yTrain3)

preds3 = model3.predict(xTest3)
r23 = model3.score(xTest3, yTest3)
rmse3 = mean_squared_error(yTest3, preds3, squared=False)
print("RMSE:", rmse3, "\nR2:", r23)
# Out:
# RMSE: 2.447068402830036e-07
# R2: 1.0
